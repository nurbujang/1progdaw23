# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('simcho.csv')

# %%
df.head()
# Out:
#       templg    oxygenn  glucosen  lactaten         fvcde
# 0  30.750815  57.057495  1.060566  1.448283  1.528810e+07
# 1  37.634444  39.625188  5.110543 -0.898456  1.775936e+07
# 2  36.219954  99.970903  6.472934  1.655867  2.568624e+06
# 3  35.789473  68.007966  0.691583  1.405390  2.482358e+06
# 4  37.727808  48.156462  6.811955  2.881147  2.716113e+07

# %%
list(df.columns[:-1])
# Out:
# ['templg', 'oxygenn', 'glucosen', 'lactaten']

# %%
px.scatter(df, x='fvcde', y=list(df.columns[:-1]))

# %% [markdown]
# where did you find relationship before?  if sthere is no relationship, then what is the effect on fvcd? there was a relationship before when i seeded at 42. now no m
# then what to write? what is the effect of seed?hello? hello what? what to write? i asked a question. what is the effect of seed? i got linear between lactate and glucose and those 2 with fvcde. i think you did something else. if there's relationship only with one seed, then there was no relationship to begin with. where is your observed data?chorimil

# %%
df_observed = pd.read_csv('chorimil.csv')

# %%
df_observed.head()
# Out:
#    temp  oxygen  glucose  lactate      fvcd
# 0  37.0     NaN      NaN     9.58   2200000
# 1  33.0     NaN      NaN     9.80   2100000
# 2  37.0    50.0      7.2     5.80  25000000
# 3  37.0    30.0      8.0     6.00  35000000
# 4  32.0    50.0      8.2     1.10  70000000

# %%
px.scatter(df_observed, x='fvcd', y=list(df_observed.columns[:-1]))

# %% [markdown]
# theres no relationship at all. ok then what to write? No relationship?
